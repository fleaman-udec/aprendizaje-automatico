# %% [markdown]
# # Redes neuronales recurrentes

# %% [markdown]
# ## Fundamentos
# Clase de red neuronal artificial usada para procesamiento de **datos secuenciales**
#
# <center>
#     <img src="figures/rnn-1.jpeg" width="700"/>
# </center>
#
# Trabaja con datos en diferentes pasos de tiempo, haciéndolas útiles para:
# - Procesamiento de texto
# - Procesamiento del habla
# - Procesamiento de series de tiempo

# %% [markdown]
# Las conexiones entre unidades pueden crear **ciclos**, por lo que la salida de una neurona puede afectar a su propia entrada.
#
# <center>
#     <img src="figures/recurrent-1.png" width="500"/>
# </center>
#
# Son especialmente útiles para modelar comportamiento **temporales** o dinámicos.

# %% [markdown]
# ## Unidad recurrente
# Es la **pieza fundamental** de una RNN ya que mantiene un estado oculto que se actualiza a cada paso de tiempo dependiendo del input actual y del estado oculto anterior.
#
# <center>
#     <img src="figures/rnn-3.png" width="500"/>
# </center>
#
# Esto funciona como una especie de **memoria** del estado oculto en base a los datos temporales anteriores

# %% [markdown]
# <center>
#     <img src="figures/rnn-5.png" width="400"/>
# </center>
#
# \begin{split}
#     h_t = f( w_{xh} x_t + w_{hh} h_{t-1} )
# \end{split}
#
# \begin{split}
#     y_t = f( w_{hy} h_{t} )
# \end{split}

# %% [markdown]
# <center>
#     <img src="figures/rnn-4.png" width="1400"/>
# </center>

# %% [markdown]
# ## Backpropagation through time  (BPTT)
# Es una adaptación del algoritmo de backpropagation para optimizar los pesos en una RNN.
#
# La función de costo total se expresa como la suma del costo en cada instante de tiempo:
#
# \begin{split}
#     S(w) = \sum_{t=1}^{T} S_t(w)
# \end{split}
#
# Del mismo modo su diferencial es:
#
# \begin{split}
#     \frac{\partial S(w)}{\partial w} = \sum_{t=1}^{T} \frac{\partial S_t(w)}{\partial w}
# \end{split}

# %% [markdown]
# Usando regla de la cadena se puede expresar:
#
# \begin{split}
#     \frac{\partial S_t(w)}{\partial w} = \frac{\partial S_t(w)}{\partial \hat{y_t}} \cdot \frac{\partial \hat{y_t}}{\partial w} = \frac{\partial S_t(w)}{\partial \hat{y_t}} \cdot \frac{\partial \hat{y_t}}{\partial h_t} \cdot \frac{\partial h_t}{\partial w}
# \end{split}
#
# Los dos primeros factores se calculan de forma directa, pero en el tercero se debe poner atención a la **recurrencia**:
# - $h_t$ depende de $h_{t-1}$ y de los pesos $w$
# - A su vez, $h_{t-1}$ también depende de los pesos $w$
#
# \begin{split}
#     \frac{\partial h_t}{\partial w} = \frac{\partial h_t}{\partial w}^{*} + \frac{\partial h_t}{\partial h_{t-1}} \frac{\partial h_{t-1}}{\partial w}
# \end{split}
#
# , donde * hace referencia a la derivada directa considerando otros valores constantes

# %% [markdown]
# # Ejemplo de Cálculo RNN

# %% [markdown]
# Supongamos una sucesión de datos: $x = \{1, 2\}$ y $y = \{3, 4\}$ para formar una RNN con los siguientes pesos iniciales:
#
# <center>
#     <img src="figures/ej-rnn-2.png" width="500"/>
# </center>
#
# Usaremos una función de costo de error cuadrático medio del tipo:
#
# \begin{split}
#     S(w) = \frac{1}{2} \sum_{i=1}^{m} (\hat{y} - y)^{2}
# \end{split}

# %% [markdown]
# Para el instante de tiempo $t=2$ se tiene:
#
#
# \begin{split}
#     \frac{\partial S_2(w)}{\partial w} = \frac{\partial S_2(w)}{\partial \hat{y_2}} \cdot \frac{\partial \hat{y_2}}{\partial h_2} \cdot \left( \frac{\partial h_2}{\partial w}^{*} + \frac{\partial h_2}{\partial h_{1}} \frac{\partial h_{1}}{\partial w} \right) = (\hat{y_2} - y_2) \cdot w_y \cdot \left( \frac{\partial h_2}{\partial w}^{*} + \frac{\partial h_2}{\partial h_{1}} \frac{\partial h_{1}}{\partial w} \right)
# \end{split}
#
# Si queremos optimizar $w_x$, entonces:
#
# \begin{split}
#     \frac{\partial S_2(w)}{\partial w_x} = (\hat{y_2} - y_2) \cdot w_y \cdot \left( x_2 + w_h x_1 \right)
# \end{split}

# %% [markdown]
# Para el instante de tiempo $t=1$ se tiene:
#
#
# \begin{split}
#     \frac{\partial S_1(w)}{\partial w} = \frac{\partial S_1(w)}{\partial \hat{y_1}} \cdot \frac{\partial \hat{y_1}}{\partial h_1} \cdot \frac{\partial h_1}{\partial w}  = (\hat{y_1} - y_1) \cdot w_y \cdot \frac{\partial h_1}{\partial w}
# \end{split}
#
# Si queremos optimizar $w_x$, entonces:
#
# \begin{split}
#     \frac{\partial S_1(w)}{\partial w_x} = (\hat{y_1} - y_1) \cdot w_y \cdot x_1
# \end{split}

# %% [markdown]
# Finalmente se tiene que:
#
# \begin{split}
#     \frac{\partial S(w)}{\partial w_x} = \sum_{t=1}^{2} \frac{\partial S_t(w)}{\partial w_x} = (\hat{y_1} - y_1) \cdot w_y \cdot \left( x_1  +  x_2 + w_h x_1 \right)
# \end{split}
#
# Utilizamos el grandiente descendente para actualizar el valor de $w_x$:
#
# \begin{split}
#     w_x := w_x - L \cdot \frac{\partial S(w)}{\partial w_x}
# \end{split}
#
# \begin{split}
#     w_x := w_x - L \cdot (\hat{y_1} - y_1) \cdot w_y \cdot \left( x_1  +  x_2 + w_h x_1 \right)
# \end{split}

# %% [markdown]
# Para la RNN del ejemplo se tiene que:
#
# \begin{split}
#     h_1 = 0.2;\quad \hat{y_1} = 0.02;\quad h_2 = 0.46;\quad \hat{y_2} = 0.046
# \end{split}
#
# Actualizamos el coeficiente $w_x$ asumiendo $L=0.1$:
# \begin{split}
#     w_x := 0.2 - 0.1 \cdot (0.02 - 3) \cdot 0.1 \cdot \left( 1  +  2 + 0.3 \cdot 1 \right) = 0.298
# \end{split}

# %% [markdown]
# Para el coeficiente $w_y$ resulta:
# \begin{split}
#     w_y := w_y - L \cdot \left( (\hat{y_1} - y_1) h_1 + (\hat{y_2} - y_2) h_2 \right)
# \end{split}
#
# \begin{split}
#     w_y := 0.1 - 0.1 \cdot \left( (0.02 - 3) 0.2 + (0.046 - 4) 0.46 \right) = 0.341
# \end{split}
#
# Para el coeficiente $w_h$ resulta:
# \begin{split}
#     w_h := w_h - L \cdot  (\hat{y_2} - y_2) w_y \cdot h_1
# \end{split}
#
# \begin{split}
#     w_h := 0.3 - 0.1 \cdot  (0.046 - 4) 0.1 \cdot 0.2  = 0.308
# \end{split}
#
# Con los ajustes las nuevas predicciones son:
#
# \begin{split}
#     h_1 = 0.298;\quad \hat{y_1} = 0.102;\quad h_2 = 0.688;\quad \hat{y_2} = 0.235
# \end{split}

# %% [markdown]
# # Predicción de series temporales con MLP y RNN

# %% [markdown]
# ## Importa módulos

# %%
import numpy as np
from tensorflow.keras import Input
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import SimpleRNN, Dense, LSTM
from tensorflow.keras.preprocessing import timeseries_dataset_from_array
from tensorflow.random import set_seed
import matplotlib.pyplot as plt
import random

np.random.seed(42)
set_seed(42)
random.seed(42)

# %% [markdown]
# ## Crea serie temporal simple

# %%
sequence = np.array([i for i in range(50)])

seq_length = 5
data_train = timeseries_dataset_from_array(data=sequence[:-5], targets=sequence[5:], sequence_length=seq_length, batch_size=1)
print(len(data_train))

count = 0
for batch in data_train:
    if count % 10 == 0:
        print(batch)
    count +=1
# Out:
# 41
# (<tf.Tensor: shape=(1, 5), dtype=int64, numpy=array([[0, 1, 2, 3, 4]])>, <tf.Tensor: shape=(1,), dtype=int64, numpy=array([5])>)
# (<tf.Tensor: shape=(1, 5), dtype=int64, numpy=array([[10, 11, 12, 13, 14]])>, <tf.Tensor: shape=(1,), dtype=int64, numpy=array([15])>)
# (<tf.Tensor: shape=(1, 5), dtype=int64, numpy=array([[20, 21, 22, 23, 24]])>, <tf.Tensor: shape=(1,), dtype=int64, numpy=array([25])>)
# (<tf.Tensor: shape=(1, 5), dtype=int64, numpy=array([[30, 31, 32, 33, 34]])>, <tf.Tensor: shape=(1,), dtype=int64, numpy=array([35])>)
# (<tf.Tensor: shape=(1, 5), dtype=int64, numpy=array([[40, 41, 42, 43, 44]])>, <tf.Tensor: shape=(1,), dtype=int64, numpy=array([45])>)

# %% [markdown]
# ## Define modelo MLP y entrena

# %%
model = Sequential([
    Input(shape=(seq_length,)),
    Dense(5, activation='relu'),
    Dense(1)
])

model.compile(optimizer='adam', loss='mse')
print(model.summary())
model.fit(data_train, epochs=100, verbose=2, shuffle=True)
# Out:
# Model: "sequential_11"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_22 (Dense)            (None, 5)                 30
#
#  dense_23 (Dense)            (None, 1)                 6
#
# =================================================================
# Total params: 36
# Trainable params: 36
# Non-trainable params: 0
# _________________________________________________________________
# None
# Epoch 1/100
# 41/41 - 0s - loss: 908.7223 - 488ms/epoch - 12ms/step
# Epoch 2/100
# 41/41 - 0s - loss: 533.8671 - 113ms/epoch - 3ms/step
# Epoch 3/100
# 41/41 - 0s - loss: 366.3891 - 125ms/epoch - 3ms/step
# Epoch 4/100
# 41/41 - 0s - loss: 243.3547 - 105ms/epoch - 3ms/step
# Epoch 5/100
# 41/41 - 0s - loss: 151.6446 - 105ms/epoch - 3ms/step
# Epoch 6/100
# 41/41 - 0s - loss: 87.4989 - 85ms/epoch - 2ms/step
# Epoch 7/100
# 41/41 - 0s - loss: 46.7668 - 86ms/epoch - 2ms/step
# Epoch 8/100
# 41/41 - 0s - loss: 23.9448 - 86ms/epoch - 2ms/step
# Epoch 9/100
# 41/41 - 0s - loss: 12.1631 - 87ms/epoch - 2ms/step
# Epoch 10/100
# 41/41 - 0s - loss: 6.1911 - 83ms/epoch - 2ms/step
# Epoch 11/100
# 41/41 - 0s - loss: 3.4521 - 87ms/epoch - 2ms/step
# Epoch 12/100
# 41/41 - 0s - loss: 2.3184 - 102ms/epoch - 2ms/step
# Epoch 13/100
# 41/41 - 0s - loss: 1.8759 - 88ms/epoch - 2ms/step
# Epoch 14/100
# 41/41 - 0s - loss: 1.7112 - 83ms/epoch - 2ms/step
# Epoch 15/100
# 41/41 - 0s - loss: 1.6445 - 84ms/epoch - 2ms/step
# Epoch 16/100
# 41/41 - 0s - loss: 1.6164 - 87ms/epoch - 2ms/step
# Epoch 17/100
# 41/41 - 0s - loss: 1.5983 - 91ms/epoch - 2ms/step
# Epoch 18/100
# 41/41 - 0s - loss: 1.5912 - 86ms/epoch - 2ms/step
# Epoch 19/100
# 41/41 - 0s - loss: 1.5785 - 85ms/epoch - 2ms/step
# Epoch 20/100
# 41/41 - 0s - loss: 1.5742 - 88ms/epoch - 2ms/step
# Epoch 21/100
# 41/41 - 0s - loss: 1.5660 - 103ms/epoch - 3ms/step
# Epoch 22/100
# 41/41 - 0s - loss: 1.5569 - 97ms/epoch - 2ms/step
# Epoch 23/100
# 41/41 - 0s - loss: 1.5523 - 92ms/epoch - 2ms/step
# Epoch 24/100
# 41/41 - 0s - loss: 1.5451 - 86ms/epoch - 2ms/step
# Epoch 25/100
# 41/41 - 0s - loss: 1.5353 - 88ms/epoch - 2ms/step
# Epoch 26/100
# 41/41 - 0s - loss: 1.5295 - 87ms/epoch - 2ms/step
# Epoch 27/100
# 41/41 - 0s - loss: 1.5233 - 89ms/epoch - 2ms/step
# Epoch 28/100
# 41/41 - 0s - loss: 1.5137 - 86ms/epoch - 2ms/step
# Epoch 29/100
# 41/41 - 0s - loss: 1.5062 - 86ms/epoch - 2ms/step
# Epoch 30/100
# 41/41 - 0s - loss: 1.4967 - 97ms/epoch - 2ms/step
# Epoch 31/100
# 41/41 - 0s - loss: 1.4912 - 84ms/epoch - 2ms/step
# Epoch 32/100
# 41/41 - 0s - loss: 1.4794 - 87ms/epoch - 2ms/step
# Epoch 33/100
# 41/41 - 0s - loss: 1.4712 - 86ms/epoch - 2ms/step
# Epoch 34/100
# 41/41 - 0s - loss: 1.4626 - 88ms/epoch - 2ms/step
# Epoch 35/100
# 41/41 - 0s - loss: 1.4537 - 85ms/epoch - 2ms/step
# Epoch 36/100
# 41/41 - 0s - loss: 1.4441 - 86ms/epoch - 2ms/step
# Epoch 37/100
# 41/41 - 0s - loss: 1.4357 - 87ms/epoch - 2ms/step
# Epoch 38/100
# 41/41 - 0s - loss: 1.4269 - 86ms/epoch - 2ms/step
# Epoch 39/100
# 41/41 - 0s - loss: 1.4174 - 100ms/epoch - 2ms/step
# Epoch 40/100
# 41/41 - 0s - loss: 1.4076 - 97ms/epoch - 2ms/step
# Epoch 41/100
# 41/41 - 0s - loss: 1.3962 - 96ms/epoch - 2ms/step
# Epoch 42/100
# 41/41 - 0s - loss: 1.3855 - 92ms/epoch - 2ms/step
# Epoch 43/100
# 41/41 - 0s - loss: 1.3767 - 87ms/epoch - 2ms/step
# Epoch 44/100
# 41/41 - 0s - loss: 1.3653 - 84ms/epoch - 2ms/step
# Epoch 45/100
# 41/41 - 0s - loss: 1.3561 - 87ms/epoch - 2ms/step
# Epoch 46/100
# 41/41 - 0s - loss: 1.3454 - 104ms/epoch - 3ms/step
# Epoch 47/100
# 41/41 - 0s - loss: 1.3334 - 96ms/epoch - 2ms/step
# Epoch 48/100
# 41/41 - 0s - loss: 1.3226 - 99ms/epoch - 2ms/step
# Epoch 49/100
# 41/41 - 0s - loss: 1.3094 - 90ms/epoch - 2ms/step
# Epoch 50/100
# 41/41 - 0s - loss: 1.3003 - 90ms/epoch - 2ms/step
# Epoch 51/100
# 41/41 - 0s - loss: 1.2890 - 93ms/epoch - 2ms/step
# Epoch 52/100
# 41/41 - 0s - loss: 1.2787 - 86ms/epoch - 2ms/step
# Epoch 53/100
# 41/41 - 0s - loss: 1.2665 - 85ms/epoch - 2ms/step
# Epoch 54/100
# 41/41 - 0s - loss: 1.2555 - 87ms/epoch - 2ms/step
# Epoch 55/100
# 41/41 - 0s - loss: 1.2424 - 88ms/epoch - 2ms/step
# Epoch 56/100
# 41/41 - 0s - loss: 1.2309 - 87ms/epoch - 2ms/step
# Epoch 57/100
# 41/41 - 0s - loss: 1.2175 - 97ms/epoch - 2ms/step
# Epoch 58/100
# 41/41 - 0s - loss: 1.2066 - 126ms/epoch - 3ms/step
# Epoch 59/100
# 41/41 - 0s - loss: 1.1947 - 103ms/epoch - 3ms/step
# Epoch 60/100
# 41/41 - 0s - loss: 1.1817 - 93ms/epoch - 2ms/step
# Epoch 61/100
# 41/41 - 0s - loss: 1.1695 - 93ms/epoch - 2ms/step
# Epoch 62/100
# 41/41 - 0s - loss: 1.1564 - 85ms/epoch - 2ms/step
# Epoch 63/100
# 41/41 - 0s - loss: 1.1438 - 82ms/epoch - 2ms/step
# Epoch 64/100
# 41/41 - 0s - loss: 1.1297 - 82ms/epoch - 2ms/step
# Epoch 65/100
# 41/41 - 0s - loss: 1.1173 - 88ms/epoch - 2ms/step
# Epoch 66/100
# 41/41 - 0s - loss: 1.1036 - 95ms/epoch - 2ms/step
# Epoch 67/100
# 41/41 - 0s - loss: 1.0892 - 88ms/epoch - 2ms/step
# Epoch 68/100
# 41/41 - 0s - loss: 1.0775 - 88ms/epoch - 2ms/step
# Epoch 69/100
# 41/41 - 0s - loss: 1.0639 - 89ms/epoch - 2ms/step
# Epoch 70/100
# 41/41 - 0s - loss: 1.0487 - 85ms/epoch - 2ms/step
# Epoch 71/100
# 41/41 - 0s - loss: 1.0358 - 86ms/epoch - 2ms/step
# Epoch 72/100
# 41/41 - 0s - loss: 1.0229 - 86ms/epoch - 2ms/step
# Epoch 73/100
# 41/41 - 0s - loss: 1.0098 - 88ms/epoch - 2ms/step
# Epoch 74/100
# 41/41 - 0s - loss: 0.9952 - 94ms/epoch - 2ms/step
# Epoch 75/100
# 41/41 - 0s - loss: 0.9813 - 105ms/epoch - 3ms/step
# Epoch 76/100
# 41/41 - 0s - loss: 0.9671 - 92ms/epoch - 2ms/step
# Epoch 77/100
# 41/41 - 0s - loss: 0.9524 - 89ms/epoch - 2ms/step
# Epoch 78/100
# 41/41 - 0s - loss: 0.9397 - 98ms/epoch - 2ms/step
# Epoch 79/100
# 41/41 - 0s - loss: 0.9255 - 92ms/epoch - 2ms/step
# Epoch 80/100
# 41/41 - 0s - loss: 0.9112 - 97ms/epoch - 2ms/step
# Epoch 81/100
# 41/41 - 0s - loss: 0.8969 - 85ms/epoch - 2ms/step
# Epoch 82/100
# 41/41 - 0s - loss: 0.8814 - 86ms/epoch - 2ms/step
# Epoch 83/100
# 41/41 - 0s - loss: 0.8679 - 95ms/epoch - 2ms/step
# Epoch 84/100
# 41/41 - 0s - loss: 0.8544 - 92ms/epoch - 2ms/step
# Epoch 85/100
# 41/41 - 0s - loss: 0.8396 - 89ms/epoch - 2ms/step
# Epoch 86/100
# 41/41 - 0s - loss: 0.8243 - 89ms/epoch - 2ms/step
# Epoch 87/100
# 41/41 - 0s - loss: 0.8105 - 89ms/epoch - 2ms/step
# Epoch 88/100
# 41/41 - 0s - loss: 0.7970 - 95ms/epoch - 2ms/step
# Epoch 89/100
# 41/41 - 0s - loss: 0.7821 - 87ms/epoch - 2ms/step
# Epoch 90/100
# 41/41 - 0s - loss: 0.7683 - 88ms/epoch - 2ms/step
# Epoch 91/100
# 41/41 - 0s - loss: 0.7541 - 88ms/epoch - 2ms/step
# Epoch 92/100
# 41/41 - 0s - loss: 0.7390 - 90ms/epoch - 2ms/step
# Epoch 93/100
# 41/41 - 0s - loss: 0.7226 - 87ms/epoch - 2ms/step
# Epoch 94/100
# 41/41 - 0s - loss: 0.7084 - 91ms/epoch - 2ms/step
# Epoch 95/100
# 41/41 - 0s - loss: 0.6956 - 87ms/epoch - 2ms/step
# Epoch 96/100
# 41/41 - 0s - loss: 0.6817 - 88ms/epoch - 2ms/step
# Epoch 97/100
# 41/41 - 0s - loss: 0.6678 - 88ms/epoch - 2ms/step
# Epoch 98/100
# 41/41 - 0s - loss: 0.6512 - 94ms/epoch - 2ms/step
# Epoch 99/100
# 41/41 - 0s - loss: 0.6379 - 92ms/epoch - 2ms/step
# Epoch 100/100
# 41/41 - 0s - loss: 0.6227 - 101ms/epoch - 2ms/step

# %% [markdown]
# ## Realiza algunas predicciones

# %%
test_input = np.array([[45, 46, 47, 48, 49]])
test_input = np.array([[45, 46, 47, 48, 49], [95, 96, 97, 98, 99]])
print(test_input.shape)

predicted_number = model.predict(test_input, verbose=0)
print("Predicted next number in sequence:", predicted_number)
print(predicted_number.shape)
# Out:
# (2, 5)
# Predicted next number in sequence: [[ 50.679096]
#  [102.44589 ]]
# (2, 1)

# %% [markdown]
# ## Crea serie temporal más compleja

# %%
n_points = 1000
time_steps = np.linspace(0, 1000, n_points) 
high_freq_sine_wave = np.sin(0.5*time_steps)
low_freq_sine_wave = 2*np.sin(time_steps / 5)
sequence = high_freq_sine_wave + 0.5 * low_freq_sine_wave + 0.2 * np.random.normal(size=n_points)

seq_length = 100
data_train = timeseries_dataset_from_array(data=sequence[:-seq_length], targets=sequence[seq_length:], sequence_length=seq_length, batch_size=1)
print(len(data_train))

plt.figure(figsize=(14,4))
plt.xlim(0, 2000)
plt.plot(time_steps, sequence)
plt.show()
# Out:
# 801

# %% [markdown]
# ## Crea modelo MLP y lo entrena

# %%
model_mlp = Sequential([
    Input(shape=(seq_length,)),
    Dense(5, activation='relu'),
    Dense(1)
])

model_mlp.compile(optimizer='adam', loss='mse')
print(model_mlp.summary())
model_mlp.fit(data_train, epochs=10, verbose=2, shuffle=True)
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ dense (Dense)                        │ (None, 5)                   │             505 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_1 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 511 (2.00 KB)
#  Trainable params: 511 (2.00 KB)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/10
# 801/801 - 1s - 2ms/step - loss: 0.3984
# Epoch 2/10
# 801/801 - 1s - 691us/step - loss: 0.0850
# Epoch 3/10
# 801/801 - 1s - 774us/step - loss: 0.0727
# Epoch 4/10
# 801/801 - 1s - 825us/step - loss: 0.0640
# Epoch 5/10
# 801/801 - 1s - 874us/step - loss: 0.0582
# Epoch 6/10
# 801/801 - 1s - 997us/step - loss: 0.0546
# Epoch 7/10
# 801/801 - 1s - 878us/step - loss: 0.0534
# Epoch 8/10
# 801/801 - 1s - 849us/step - loss: 0.0523
# Epoch 9/10
# 801/801 - 1s - 928us/step - loss: 0.0503
# Epoch 10/10
# 801/801 - 1s - 879us/step - loss: 0.0489

# %% [markdown]
# ## Continúa el entrenamiento

# %%
model_mlp.fit(data_train, epochs=100, verbose=2, shuffle=True, initial_epoch=50)
# Out:
# Epoch 51/100
# 801/801 - 2s - loss: 0.0375 - 2s/epoch - 2ms/step
# Epoch 52/100
# 801/801 - 2s - loss: 0.0374 - 2s/epoch - 2ms/step
# Epoch 53/100
# 801/801 - 2s - loss: 0.0372 - 2s/epoch - 2ms/step
# Epoch 54/100
# 801/801 - 2s - loss: 0.0372 - 2s/epoch - 2ms/step
# Epoch 55/100
# 801/801 - 2s - loss: 0.0375 - 2s/epoch - 2ms/step
# Epoch 56/100
# 801/801 - 2s - loss: 0.0370 - 2s/epoch - 2ms/step
# Epoch 57/100
# 801/801 - 2s - loss: 0.0370 - 2s/epoch - 2ms/step
# Epoch 58/100
# 801/801 - 2s - loss: 0.0368 - 2s/epoch - 2ms/step
# Epoch 59/100
# 801/801 - 2s - loss: 0.0367 - 2s/epoch - 2ms/step
# Epoch 60/100
# 801/801 - 2s - loss: 0.0367 - 2s/epoch - 2ms/step
# Epoch 61/100
# 801/801 - 2s - loss: 0.0366 - 2s/epoch - 2ms/step
# Epoch 62/100
# 801/801 - 2s - loss: 0.0365 - 2s/epoch - 2ms/step
# Epoch 63/100
# 801/801 - 2s - loss: 0.0365 - 2s/epoch - 2ms/step
# Epoch 64/100
# 801/801 - 2s - loss: 0.0361 - 2s/epoch - 2ms/step
# Epoch 65/100
# 801/801 - 2s - loss: 0.0362 - 2s/epoch - 2ms/step
# Epoch 66/100
# 801/801 - 2s - loss: 0.0361 - 2s/epoch - 2ms/step
# Epoch 67/100
# 801/801 - 2s - loss: 0.0361 - 2s/epoch - 2ms/step
# Epoch 68/100
# 801/801 - 2s - loss: 0.0359 - 2s/epoch - 2ms/step
# Epoch 69/100
# 801/801 - 2s - loss: 0.0359 - 2s/epoch - 2ms/step
# Epoch 70/100
# 801/801 - 2s - loss: 0.0358 - 2s/epoch - 2ms/step
# Epoch 71/100
# 801/801 - 2s - loss: 0.0357 - 2s/epoch - 2ms/step
# Epoch 72/100
# 801/801 - 2s - loss: 0.0355 - 2s/epoch - 2ms/step
# Epoch 73/100
# 801/801 - 2s - loss: 0.0356 - 2s/epoch - 2ms/step
# Epoch 74/100
# 801/801 - 2s - loss: 0.0354 - 2s/epoch - 2ms/step
# Epoch 75/100
# 801/801 - 2s - loss: 0.0355 - 2s/epoch - 2ms/step
# Epoch 76/100
# 801/801 - 2s - loss: 0.0354 - 2s/epoch - 2ms/step
# Epoch 77/100
# 801/801 - 2s - loss: 0.0354 - 2s/epoch - 2ms/step
# Epoch 78/100
# 801/801 - 2s - loss: 0.0356 - 2s/epoch - 2ms/step
# Epoch 79/100
# 801/801 - 2s - loss: 0.0353 - 2s/epoch - 2ms/step
# Epoch 80/100
# 801/801 - 2s - loss: 0.0352 - 2s/epoch - 2ms/step
# Epoch 81/100
# 801/801 - 2s - loss: 0.0353 - 2s/epoch - 2ms/step
# Epoch 82/100
# 801/801 - 2s - loss: 0.0350 - 2s/epoch - 2ms/step
# Epoch 83/100
# 801/801 - 2s - loss: 0.0349 - 2s/epoch - 2ms/step
# Epoch 84/100
# 801/801 - 2s - loss: 0.0347 - 2s/epoch - 2ms/step
# Epoch 85/100
# 801/801 - 2s - loss: 0.0349 - 2s/epoch - 2ms/step
# Epoch 86/100
# 801/801 - 2s - loss: 0.0351 - 2s/epoch - 2ms/step
# Epoch 87/100
# 801/801 - 2s - loss: 0.0348 - 2s/epoch - 2ms/step
# Epoch 88/100
# 801/801 - 2s - loss: 0.0348 - 2s/epoch - 2ms/step
# Epoch 89/100
# 801/801 - 2s - loss: 0.0348 - 2s/epoch - 2ms/step
# Epoch 90/100
# 801/801 - 2s - loss: 0.0348 - 2s/epoch - 2ms/step
# Epoch 91/100
# 801/801 - 2s - loss: 0.0346 - 2s/epoch - 2ms/step
# Epoch 92/100
# 801/801 - 2s - loss: 0.0346 - 2s/epoch - 2ms/step
# Epoch 93/100
# 801/801 - 2s - loss: 0.0344 - 2s/epoch - 3ms/step
# Epoch 94/100
# 801/801 - 3s - loss: 0.0346 - 3s/epoch - 3ms/step
# Epoch 95/100
# 801/801 - 2s - loss: 0.0344 - 2s/epoch - 3ms/step
# Epoch 96/100
# 801/801 - 2s - loss: 0.0345 - 2s/epoch - 2ms/step
# Epoch 97/100
# 801/801 - 2s - loss: 0.0343 - 2s/epoch - 2ms/step
# Epoch 98/100
# 801/801 - 2s - loss: 0.0344 - 2s/epoch - 2ms/step
# Epoch 99/100
# 801/801 - 2s - loss: 0.0341 - 2s/epoch - 3ms/step
# Epoch 100/100
# 801/801 - 2s - loss: 0.0342 - 2s/epoch - 3ms/step

# %% [markdown]
# ## Realiza predicciones hacia adelante con MLP

# %%
further_points = 1000
further_time_steps = np.linspace(1000, 2000, further_points) 

predictions = []
input_seq = sequence[-seq_length:] #secuencia inicial (últimos puntos anteriores)

for _ in range(further_points): #predice siguientes puntos
    input_seq_expand = np.expand_dims(input_seq, axis=0)
    predicted_point = model_mlp.predict(input_seq_expand, verbose=0)
    predictions.append(predicted_point[0][0])
    input_seq = np.append(input_seq[1:], predicted_point)  #corre la ventana

plt.figure(figsize=(14, 4))
plt.plot(time_steps, sequence, label='Time series')
plt.plot(further_time_steps, predictions, label='Prediction MLP', color='red')
plt.legend()
plt.show()

# %% [markdown]
# ## Crea modelo RNN y lo entrena

# %%
model_rnn = Sequential([
    Input(shape=(seq_length, 1)),
    SimpleRNN(5, activation='tanh'),
    Dense(1)
])

model_rnn.compile(optimizer='adam', loss='mse')
print(model_rnn.summary())
model_rnn.fit(data_train, epochs=10, verbose=2, shuffle=True)
# Out:
# Model: "sequential_2"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ simple_rnn (SimpleRNN)               │ (None, 5)                   │              35 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_3 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 41 (164.00 B)
#  Trainable params: 41 (164.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/10
# 801/801 - 6s - 7ms/step - loss: 0.7179
# Epoch 2/10
# 801/801 - 5s - 6ms/step - loss: 0.2476
# Epoch 3/10
# 801/801 - 5s - 6ms/step - loss: 0.1660
# Epoch 4/10
# 801/801 - 5s - 6ms/step - loss: 0.1442
# Epoch 5/10
# 801/801 - 5s - 6ms/step - loss: 0.1339
# Epoch 6/10
# 801/801 - 5s - 6ms/step - loss: 0.1276
# Epoch 7/10
# 801/801 - 5s - 6ms/step - loss: 0.1234
# Epoch 8/10
# 801/801 - 5s - 6ms/step - loss: 0.1203
# Epoch 9/10
# 801/801 - 5s - 6ms/step - loss: 0.1177
# Epoch 10/10
# 801/801 - 5s - 6ms/step - loss: 0.1153

# %% [markdown]
# ## Continúa entrenamiento

# %%
model_rnn.fit(data_train, epochs=20, verbose=2, shuffle=True, initial_epoch=10)
# Out:
# Epoch 11/20
# 801/801 - 61s - loss: 0.1122 - 61s/epoch - 76ms/step
# Epoch 12/20
# 801/801 - 61s - loss: 0.1087 - 61s/epoch - 76ms/step
# Epoch 13/20
# 801/801 - 62s - loss: 0.1035 - 62s/epoch - 77ms/step
# Epoch 14/20
# 801/801 - 66s - loss: 0.0998 - 66s/epoch - 83ms/step
# Epoch 15/20
# 801/801 - 67s - loss: 0.0980 - 67s/epoch - 83ms/step
# Epoch 16/20
# 801/801 - 62s - loss: 0.0970 - 62s/epoch - 78ms/step
# Epoch 17/20
# 801/801 - 62s - loss: 0.0964 - 62s/epoch - 78ms/step
# Epoch 18/20
# 801/801 - 68s - loss: 0.0959 - 68s/epoch - 85ms/step
# Epoch 19/20
# 801/801 - 64s - loss: 0.0956 - 64s/epoch - 80ms/step
# Epoch 20/20
# 801/801 - 62s - loss: 0.0953 - 62s/epoch - 77ms/step

# %% [markdown]
# ## Realiza predicciones hacia adelante con RNN

# %%
further_points = 1000
further_time_steps = np.linspace(1000, 2000, further_points) 

predictions = []
input_seq = sequence[-seq_length:] #secuencia inicial (últimos puntos anteriores)

for _ in range(further_points): #predice siguientes puntos
    input_seq_expand = np.expand_dims(input_seq, axis=0)
    predicted_point = model_rnn.predict(input_seq_expand, verbose=0)
    predictions.append(predicted_point[0][0])
    input_seq = np.append(input_seq[1:], predicted_point)  #corre la ventana

plt.figure(figsize=(14, 4))
plt.plot(time_steps, sequence, label='Time series')
plt.plot(further_time_steps, predictions, label='Prediction RNN', color='red')
plt.legend()
plt.show()

# %% [markdown]
# # Red recurrente LSTM

# %% [markdown]
# La arquitectura original de una RNN sufre del problema de **desvanecimiento del gradiente** para dependencias temporales de largo alcance.
#
# <center>
#     <img src="figures/vanishing-gradient.png" width="500"/>
# </center>
# Esto significa que los gradientes se vuelven muy cercanos a cero, haciendo imposible la correcta actualización de coeficientes

# %% [markdown]
# La red LSTM (long-short) resuelve este problema implementando una estructura que permite "recordar" u "olvidar" datos  dentro de la secuencia
#
# <center>
#     <img src="figures/rnn-vs-lstm.png" width="500"/>
# </center>

# %% [markdown]
# ## Crea y entrena LSTM para serie de tiempo

# %%
model_lstm = Sequential([
    Input(shape=(seq_length, 1)),
    LSTM(5, activation='tanh'),
    Dense(1)
])

model_lstm.compile(optimizer='adam', loss='mse')
print(model_lstm.summary())
model_lstm.fit(data_train, epochs=10, verbose=2, shuffle=True)
# Out:
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                         ┃ Output Shape                ┃         Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                          │ (None, 5)                   │             140 │
# ├──────────────────────────────────────┼─────────────────────────────┼─────────────────┤
# │ dense_2 (Dense)                      │ (None, 1)                   │               6 │
# └──────────────────────────────────────┴─────────────────────────────┴─────────────────┘
#  Total params: 146 (584.00 B)
#  Trainable params: 146 (584.00 B)
#  Non-trainable params: 0 (0.00 B)
# None
# Epoch 1/10
# 801/801 - 10s - 12ms/step - loss: 0.6915
# Epoch 2/10
# 801/801 - 8s - 10ms/step - loss: 0.2994
# Epoch 3/10
# 801/801 - 8s - 10ms/step - loss: 0.1771
# Epoch 4/10
# 801/801 - 8s - 10ms/step - loss: 0.1253
# Epoch 5/10
# 801/801 - 8s - 10ms/step - loss: 0.0984
# Epoch 6/10
# 801/801 - 8s - 10ms/step - loss: 0.0903
# Epoch 7/10
# 801/801 - 8s - 10ms/step - loss: 0.0856
# Epoch 8/10
# 801/801 - 10s - 13ms/step - loss: 0.0815
# Epoch 9/10
# 801/801 - 8s - 10ms/step - loss: 0.0780
# Epoch 10/10
# 801/801 - 8s - 10ms/step - loss: 0.0751

# %% [markdown]
# ## Continúa el entrenamiento

# %%
model_lstm.fit(data_train, epochs=100, verbose=2, shuffle=True, initial_epoch=10)
# Out:
# Epoch 11/100
# 801/801 - 6s - loss: 0.1364 - 6s/epoch - 7ms/step
# Epoch 12/100
# 801/801 - 5s - loss: 0.1326 - 5s/epoch - 7ms/step
# Epoch 13/100
# 801/801 - 6s - loss: 0.1286 - 6s/epoch - 7ms/step
# Epoch 14/100
# 801/801 - 6s - loss: 0.1208 - 6s/epoch - 7ms/step
# Epoch 15/100
# 801/801 - 6s - loss: 0.1156 - 6s/epoch - 7ms/step
# Epoch 16/100
# 801/801 - 6s - loss: 0.1109 - 6s/epoch - 7ms/step
# Epoch 17/100
# 801/801 - 6s - loss: 0.1127 - 6s/epoch - 7ms/step
# Epoch 18/100
# 801/801 - 6s - loss: 0.1073 - 6s/epoch - 7ms/step
# Epoch 19/100
# 801/801 - 6s - loss: 0.1092 - 6s/epoch - 7ms/step
# Epoch 20/100
# 801/801 - 6s - loss: 0.1018 - 6s/epoch - 7ms/step
# Epoch 21/100
# 801/801 - 6s - loss: 0.0982 - 6s/epoch - 7ms/step
# Epoch 22/100
# 801/801 - 6s - loss: 0.0992 - 6s/epoch - 7ms/step
# Epoch 23/100
# 801/801 - 6s - loss: 0.0968 - 6s/epoch - 7ms/step
# Epoch 24/100
# 801/801 - 6s - loss: 0.0952 - 6s/epoch - 7ms/step
# Epoch 25/100
# 801/801 - 6s - loss: 0.0934 - 6s/epoch - 7ms/step
# Epoch 26/100
# 801/801 - 6s - loss: 0.0941 - 6s/epoch - 7ms/step
# Epoch 27/100
# 801/801 - 6s - loss: 0.0887 - 6s/epoch - 7ms/step
# Epoch 28/100
# 801/801 - 6s - loss: 0.0883 - 6s/epoch - 7ms/step
# Epoch 29/100
# 801/801 - 6s - loss: 0.0856 - 6s/epoch - 7ms/step
# Epoch 30/100
# 801/801 - 6s - loss: 0.0850 - 6s/epoch - 7ms/step
# Epoch 31/100
# 801/801 - 6s - loss: 0.0813 - 6s/epoch - 7ms/step
# Epoch 32/100
# 801/801 - 5s - loss: 0.0816 - 5s/epoch - 7ms/step
# Epoch 33/100
# 801/801 - 6s - loss: 0.0786 - 6s/epoch - 7ms/step
# Epoch 34/100
# 801/801 - 6s - loss: 0.0779 - 6s/epoch - 7ms/step
# Epoch 35/100
# 801/801 - 6s - loss: 0.0772 - 6s/epoch - 7ms/step
# Epoch 36/100
# 801/801 - 6s - loss: 0.0771 - 6s/epoch - 7ms/step
# Epoch 37/100
# 801/801 - 6s - loss: 0.0773 - 6s/epoch - 7ms/step
# Epoch 38/100
# 801/801 - 6s - loss: 0.0760 - 6s/epoch - 8ms/step
# Epoch 39/100
# 801/801 - 6s - loss: 0.0758 - 6s/epoch - 8ms/step
# Epoch 40/100
# 801/801 - 6s - loss: 0.0750 - 6s/epoch - 8ms/step
# Epoch 41/100
# 801/801 - 6s - loss: 0.0744 - 6s/epoch - 7ms/step
# Epoch 42/100
# 801/801 - 6s - loss: 0.0739 - 6s/epoch - 8ms/step
# Epoch 43/100
# 801/801 - 7s - loss: 0.0735 - 7s/epoch - 8ms/step
# Epoch 44/100
# 801/801 - 7s - loss: 0.0730 - 7s/epoch - 8ms/step
# Epoch 45/100
# 801/801 - 7s - loss: 0.0725 - 7s/epoch - 8ms/step
# Epoch 46/100
# 801/801 - 7s - loss: 0.0722 - 7s/epoch - 9ms/step
# Epoch 47/100
# 801/801 - 7s - loss: 0.0716 - 7s/epoch - 8ms/step
# Epoch 48/100
# 801/801 - 6s - loss: 0.0716 - 6s/epoch - 8ms/step
# Epoch 49/100
# 801/801 - 6s - loss: 0.0709 - 6s/epoch - 8ms/step
# Epoch 50/100
# 801/801 - 7s - loss: 0.0704 - 7s/epoch - 8ms/step
# Epoch 51/100
# 801/801 - 6s - loss: 0.0703 - 6s/epoch - 8ms/step
# Epoch 52/100
# 801/801 - 6s - loss: 0.0697 - 6s/epoch - 8ms/step
# Epoch 53/100
# 801/801 - 6s - loss: 0.0695 - 6s/epoch - 7ms/step
# Epoch 54/100
# 801/801 - 6s - loss: 0.0691 - 6s/epoch - 7ms/step
# Epoch 55/100
# 801/801 - 6s - loss: 0.0689 - 6s/epoch - 7ms/step
# Epoch 56/100
# 801/801 - 6s - loss: 0.0684 - 6s/epoch - 7ms/step
# Epoch 57/100
# 801/801 - 6s - loss: 0.0681 - 6s/epoch - 7ms/step
# Epoch 58/100
# 801/801 - 6s - loss: 0.0675 - 6s/epoch - 8ms/step
# Epoch 59/100
# 801/801 - 6s - loss: 0.0672 - 6s/epoch - 8ms/step
# Epoch 60/100
# 801/801 - 6s - loss: 0.0666 - 6s/epoch - 7ms/step
# Epoch 61/100
# 801/801 - 6s - loss: 0.0668 - 6s/epoch - 7ms/step
# Epoch 62/100
# 801/801 - 6s - loss: 0.0666 - 6s/epoch - 7ms/step
# Epoch 63/100
# 801/801 - 6s - loss: 0.0660 - 6s/epoch - 7ms/step
# Epoch 64/100
# 801/801 - 6s - loss: 0.0642 - 6s/epoch - 7ms/step
# Epoch 65/100
# 801/801 - 6s - loss: 0.0670 - 6s/epoch - 8ms/step
# Epoch 66/100
# 801/801 - 6s - loss: 0.0642 - 6s/epoch - 8ms/step
# Epoch 67/100
# 801/801 - 6s - loss: 0.0648 - 6s/epoch - 8ms/step
# Epoch 68/100
# 801/801 - 6s - loss: 0.0643 - 6s/epoch - 8ms/step
# Epoch 69/100
# 801/801 - 6s - loss: 0.0647 - 6s/epoch - 8ms/step
# Epoch 70/100
# 801/801 - 6s - loss: 0.0641 - 6s/epoch - 8ms/step
# Epoch 71/100
# 801/801 - 6s - loss: 0.0638 - 6s/epoch - 8ms/step
# Epoch 72/100
# 801/801 - 6s - loss: 0.0636 - 6s/epoch - 8ms/step
# Epoch 73/100
# 801/801 - 6s - loss: 0.0652 - 6s/epoch - 8ms/step
# Epoch 74/100
# 801/801 - 6s - loss: 0.0622 - 6s/epoch - 8ms/step
# Epoch 75/100
# 801/801 - 7s - loss: 0.0626 - 7s/epoch - 9ms/step
# Epoch 76/100
# 801/801 - 7s - loss: 0.0634 - 7s/epoch - 9ms/step
# Epoch 77/100
# 801/801 - 7s - loss: 0.0622 - 7s/epoch - 9ms/step
# Epoch 78/100
# 801/801 - 7s - loss: 0.0635 - 7s/epoch - 9ms/step
# Epoch 79/100
# 801/801 - 7s - loss: 0.0630 - 7s/epoch - 9ms/step
# Epoch 80/100
# 801/801 - 7s - loss: 0.0624 - 7s/epoch - 9ms/step
# Epoch 81/100
# 801/801 - 7s - loss: 0.0614 - 7s/epoch - 8ms/step
# Epoch 82/100
# 801/801 - 7s - loss: 0.0633 - 7s/epoch - 8ms/step
# Epoch 83/100
# 801/801 - 7s - loss: 0.0611 - 7s/epoch - 8ms/step
# Epoch 84/100
# 801/801 - 6s - loss: 0.0619 - 6s/epoch - 8ms/step
# Epoch 85/100
# 801/801 - 6s - loss: 0.0594 - 6s/epoch - 8ms/step
# Epoch 86/100
# 801/801 - 6s - loss: 0.0593 - 6s/epoch - 8ms/step
# Epoch 87/100
# 801/801 - 6s - loss: 0.0595 - 6s/epoch - 8ms/step
# Epoch 88/100
# 801/801 - 6s - loss: 0.0588 - 6s/epoch - 8ms/step
# Epoch 89/100
# 801/801 - 6s - loss: 0.0590 - 6s/epoch - 7ms/step
# Epoch 90/100
# 801/801 - 6s - loss: 0.0596 - 6s/epoch - 8ms/step
# Epoch 91/100
# 801/801 - 6s - loss: 0.0587 - 6s/epoch - 8ms/step
# Epoch 92/100
# 801/801 - 6s - loss: 0.0597 - 6s/epoch - 8ms/step
# Epoch 93/100
# 801/801 - 6s - loss: 0.0588 - 6s/epoch - 8ms/step
# Epoch 94/100
# 801/801 - 6s - loss: 0.0579 - 6s/epoch - 7ms/step
# Epoch 95/100
# 801/801 - 6s - loss: 0.0575 - 6s/epoch - 7ms/step
# Epoch 96/100
# 801/801 - 6s - loss: 0.0577 - 6s/epoch - 7ms/step
# Epoch 97/100
# 801/801 - 6s - loss: 0.0586 - 6s/epoch - 7ms/step
# Epoch 98/100
# 801/801 - 6s - loss: 0.0578 - 6s/epoch - 7ms/step
# Epoch 99/100
# 801/801 - 6s - loss: 0.0571 - 6s/epoch - 7ms/step
# Epoch 100/100
# 801/801 - 6s - loss: 0.0567 - 6s/epoch - 7ms/step

# %% [markdown]
# ## Realiza predicciones hacia adelante con LSTM

# %%
further_points = 1000
further_time_steps = np.linspace(1000, 2000, further_points) 

predictions = []
input_seq = sequence[-seq_length:] #secuencia inicial (últimos puntos anteriores)

for _ in range(further_points): #predice siguientes puntos
    input_seq_expand = np.expand_dims(input_seq, axis=0)
    predicted_point = model_lstm.predict(input_seq_expand, verbose=0)
    predictions.append(predicted_point[0][0])
    input_seq = np.append(input_seq[1:], predicted_point)  #corre la ventana

plt.figure(figsize=(14, 4))
plt.plot(time_steps, sequence, label='Time series')
plt.plot(further_time_steps, predictions, label='Prediction LSTM', color='red')
plt.legend()
plt.show()
